# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Book.csv')

# %%
df.head()
# Out:
#   Unnamed: 0  videos  views
# 0   channel1      30  34000
# 1   channel2      40  41000
# 2   channel3      50  42500
# 3   channel4      60  54300
# 4   channel5      70  56000

# %%
# view data points
plt.scatter(df.videos, df.views, color='red')
plt.xlabel('Number of Videos')
plt.ylabel('Total Views')
# Out:
# Text(0, 0.5, 'Total Views')

# %%
x=df['videos']
y=df['views']

# %%
x=np.array(x)
y=np.array(y)

# %%
x
# Out:
# array([30, 40, 50, 60, 70])

# %%
x.reshape(-1,1)
# Out:
# array([[30],
#        [40],
#        [50],
#        [60],
#        [70]])

# %%
y
# Out:
# array([34000, 41000, 42500, 54300, 56000])

# %%
model = LinearRegression()
model.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
x_text = np.array(45).reshape(-1,1)

# %%
model.predict(x_text)
# Out:
# array([42695.])
